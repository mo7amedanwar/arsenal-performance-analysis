# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5077e972-aa55-4712-8e9d-f072025d4749" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5077e972-aa55-4712-8e9d-f072025d4749">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dad2d4bc-257e-4b95-936e-2ec58eb71463" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dad2d4bc-257e-4b95-936e-2ec58eb71463">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

arsenal = pd.read_csv(
    "premier_league_complete_stats_until31thGameDayOnSeason2025-26.csv",
    encoding="latin1"
)

# %%
arsenal.head()
# Out:
#          player_name team_name position  accurateCrosses  \
# 0        Declan Rice   Arsenal        M               41
# 1  Gabriel Magalhães   Arsenal        D                1
# 2        Bukayo Saka   Arsenal        F               36
# 3   Martín Zubimendi   Arsenal        M                2
# 4         Max Dowman   Arsenal        M                0
#
#    accurateCrossesPercentage  accurateFinalThirdPasses  accurateLongBalls  \
# 0                  28.082192                       459                 72
# 1                  20.000000                       180                 63
# 2                  32.432432                       300                 14
# 3                  18.181818                       369                 48
# 4                   0.000000                         9                  0
#
#    accurateLongBallsPercentage  accurateOppositionHalfPasses  \
# 0                    48.648649                           891
# ...

# %%
epl = pd.read_csv(
    "premier_league_complete_stats_until35thGameDayOnSeason2025-26.csv",
    encoding="latin1"
)

# %%
epl.head()
# Out:
#           player_name team_name position  accurateChippedPasses  \
# 0         Declan Rice   Arsenal        M                     64
# 1  Gabriel MagalhÃ£es   Arsenal        D                     41
# 2         Bukayo Saka   Arsenal        F                     15
# 3   MartÃ­n Zubimendi   Arsenal        M                     48
# 4      William Saliba   Arsenal        D                     26
#
#    accurateCrosses  accurateCrossesPercentage  accurateFinalThirdPasses  \
# 0               45                  27.108434                       501
# 1                1                  20.000000                       196
# 2               37                  32.173913                       314
# 3                2                  18.181818                       391
# 4                4                  44.444444                       245
#
#    accurateLongBalls  accurateLongBallsPercentage  \
# 0                 81                    49.090909
# ...

# %%
epl.columns
# Out:
# Index(['player_name', 'team_name', 'position', 'accurateChippedPasses',
#        'accurateCrosses', 'accurateCrossesPercentage',
#        'accurateFinalThirdPasses', 'accurateLongBalls',
#        'accurateLongBallsPercentage', 'accurateOppositionHalfPasses',
#        ...
#        'totalLongBalls', 'totalOppositionHalfPasses', 'totalOwnHalfPasses',
#        'totalPasses', 'totalShots', 'totwAppearances', 'touches', 'wasFouled',
#        'yellowCards', 'yellowRedCards'],
#       dtype='object', length=106)

# %%
arsenal.select_dtypes(include='number').shape
# Out:
# (517, 96)

# %%
arsenal.describe()
# Out:
#        accurateCrosses  accurateCrossesPercentage  accurateFinalThirdPasses  \
# count       517.000000                 517.000000                517.000000
# mean          5.019342                  16.213135                105.148936
# std           8.229250                  17.318549                102.643656
# min           0.000000                   0.000000                  0.000000
# 25%           0.000000                   0.000000                 25.000000
# 50%           1.000000                  15.384615                 79.000000
# 75%           7.000000                  26.666667                149.000000
# max          53.000000                 100.000000                567.000000
#
#        accurateLongBalls  accurateLongBallsPercentage  \
# count         517.000000                   517.000000
# mean           24.988395                    41.176116
# std            35.832349                    22.091051
# min             0.000000                     0.000000
# ...

# %%
arsenal.sort_values("totalPasses", ascending=False).head(10)
# Out:
#             player_name                   team_name position  accurateCrosses  \
# 106     Virgil van Dijk                   Liverpool        D                0
# 223          Lewis Dunk  Brighton &amp; Hove Albion        D                1
# 133     Trevoh Chalobah                     Chelsea        D                1
# 199    Joachim Andersen                      Fulham        D                4
# 376     Elliot Anderson           Nottingham Forest        M               43
# 220  Jan Paul van Hecke  Brighton &amp; Hove Albion        D                9
# 300       Marcos Senesi                 Bournemouth        D                7
# 81           Ezri Konsa                 Aston Villa        D                1
# 107  Dominik Szoboszlai                   Liverpool        M               53
# 0           Declan Rice                     Arsenal        M               41
#
#      accurateCrossesPercentage  accurateFinalThirdPasses  accurateLongBalls  \
# ...

# %%
arsenal["team_name"].value_counts()
# Out:
# team_name
# Nottingham Forest             30
# West Ham United               30
# Aston Villa                   29
# Sunderland                    28
# Wolverhampton                 28
# Crystal Palace                27
# Manchester United             27
# Brighton &amp; Hove Albion    27
# Tottenham Hotspur             27
# Manchester City               26
# Burnley                       26
# Bournemouth                   25
# Newcastle United              25
# Arsenal                       24
# Chelsea                       24
# Leeds United                  24
# Fulham                        23
# Brentford                     23
# Liverpool                     22
# Everton                       22
# Name: count, dtype: int64

# %%
epl_team = epl.groupby("team_name").sum(numeric_only=True)
epl_team.head()
# Out:
#                             accurateChippedPasses  accurateCrosses  \
# team_name
# Arsenal                                       415              152
# Aston Villa                                   502              126
# Bournemouth                                   455              122
# Brentford                                     510              173
# Brighton &amp; Hove Albion                    549              167
#
#                             accurateCrossesPercentage  \
# team_name
# Arsenal                                    359.090550
# Aston Villa                                366.690186
# Bournemouth                                312.003780
# Brentford                                  448.157162
# Brighton &amp; Hove Albion                 455.290174
#
#                             accurateFinalThirdPasses  accurateLongBalls  \
# team_name
# Arsenal                                         3909                653
# ...

# %%
epl_team.loc["Arsenal"]
# Out:
# accurateChippedPasses          415.00000
# accurateCrosses                152.00000
# accurateCrossesPercentage      359.09055
# accurateFinalThirdPasses      3909.00000
# accurateLongBalls              653.00000
#                                 ...
# totwAppearances                 32.00000
# touches                      22856.00000
# wasFouled                      371.00000
# yellowCards                     45.00000
# yellowRedCards                   0.00000
# Name: Arsenal, Length: 103, dtype: float64

# %%
epl_team.sort_values("totalShots", ascending=False).head(5)
# Out:
#                    accurateChippedPasses  accurateCrosses  \
# team_name
# Manchester City                      631              157
# Manchester United                    587              163
# Liverpool FC                         510              149
# Arsenal                              415              152
# Chelsea                              489              137
#
#                    accurateCrossesPercentage  accurateFinalThirdPasses  \
# team_name
# Manchester City                   593.477936                      5184
# Manchester United                 523.231579                      3465
# Liverpool FC                      306.963849                      4843
# Arsenal                           359.090550                      3909
# Chelsea                           508.311682                      3808
#
#                    accurateLongBalls  accurateLongBallsPercentage  \
# team_name
# Manchester City                  726                  1223.048717
# ...

# %%
epl_team.loc[["Arsenal", "Manchester City"]][["totalShots", "totalPasses", "touches", "wasFouled"]]
# Out:
#                  totalShots  totalPasses  touches  wasFouled
# team_name
# Arsenal                 514        16387    22856        371
# Manchester City         584        21481    28583        398

# %%
epl_team[["totalShots", "totalPasses", "touches", "wasFouled"]].sort_values("totalShots", ascending=False)
# Out:
#                             totalShots  totalPasses  touches  wasFouled
# team_name
# Manchester City                    584        21481    28583        398
# Manchester United                  545        16324    23022        367
# Liverpool FC                       541        18756    25546        351
# Arsenal                            514        16387    22856        371
# Chelsea                            484        19096    25584        397
# Newcastle United                   454        15592    22542        401
# Brighton &amp; Hove Albion         449        16532    23272        344
# Leeds United                       447        13992    20906        387
# Bournemouth                        438        13921    20738        340
# Aston Villa                        436        15936    22240        431
# Fulham                             435        16616    23219        316
# Nottingham Forest                  428        14007    20847        390
# ...

# %%
epl_team.to_csv("epl_team.csv")
